# %% [markdown]
# ## **Dataset**

# %%
{
  "intents":
  [ 
    {
      "tag": "pembuka",
            "patterns": ["hi", "hai", "hey", "hei", "apakah ada orang disana?", "hello", "halo", "hay", "ini itu apa ya?"],
            "responses": ["Hallo saya Kuji! Saya disini siap membantu kamu", "Hallo saya Kuji! Ada yang bisa saya bantu?", "Hallo saya Kuji!, asisten bot yang siap membantu kamu"]
      },
    {
            "tag": "penutup",
            "patterns": ["terima Kasih", "bye", "thanks", "thank you", "ini sangat membantu", "terima Kasih untuk bantuannya", "oke mks"],
            "responses": ["Terima Kasih sudah menggunakan TemanHewan", "Semoga lekas sembuh", "Senang bisa membantu kamu", "Sama-sama!", "Semoga semuanya segera membaik, Kuji selalu siap membantu kamu disini 24/7"]
        },
        {
            "tag": "bantuan",
            "patterns": ["tolong bantu saya", "apa yang dapat anda lakukan untuk saya?", "tolong hewan saya", "saya butuh bantuan"],
            "responses": ["Jelaskan pada saya bagaimana keadaan hewan peliharaan mu?", "Ceritakan masalah hewan kamu agar aku bisa membantu", "Apa yang terjadi pada hewan mu?", "Gejala apa yang terjadi pada hewan mu?"]
        },
        {
            "tag": "keluhan",
            "patterns": ["complaint", "komplen", "komplain", "saya ingin mengajukan keluhan", "ada masalah dengan layanan"],
            "responses": ["Silahkan hubungi support@temanhewan.com dan mohon maaf atas ketidaknyamanan yang ditimbulkan"]
        },  
    {
        "tag": "Rabies",
        "patterns": ["Anjing saya suka bersembunyi di tempat sunyi. Kadang dia juga cepat marah atau berlari kesana kemari. Diberi makan ngga mau, diberi minum malah takut. Air liurnya kadang bocor juga kayak gila gitu", "anjing saya terus bersembunyi ditempat sunyi dan marah-marah. Ia juga takut terhadap air serta terus mengeluarkan air liur. Ia tidak mau makan dan terus lari-larian.", "kenapa anjing saya jadi cepat marah dan ga mau makan? dia juga sering ngumpet di tempat sepi, lari sono sini, keluar iler trus takut aer juga itu kenapa ya? "],
        "responses": ["Definisi:\nRabies adalah infeksi virus pada otak dan sistem saraf. Umumnya, virus penyebab rabies menular ke manusia melalui gigitan hewan. Rabies tergolong penyakit berbahaya karena berisiko menyebabkan kematian jika tidak cepat ditangani.\n\nPenyebab:\nRabies disebabkan oleh virus yang umumnya ditularkan dari anjing melalui gigitan, cakaran, atau air liur. Selain anjing, hewan yang juga dapat membawa virus rabies dan menularkannya ke manusia antara lain kera, kucing, musang, dan kelinci. Pada kasus yang jarang terjadi, penularan virus rabies juga dapat terjadi dari manusia ke manusia, melalui transplantasi organ.\n\nPenanganan:\nDibawa ke Dinas Peternakan atau dokter hewan yang berwenang. "],
        "context_set": [""]
    },
    {
        "tag": "Scabies",
        "patterns": ["Anjing saya ada lecet sama lesi di ujung telinganya, kerak, bintik botak di sekitar kepala. Bulu ekornya kadang rontok kadang berminyak. Bulu yang lain juga rontok. Yang saya takutkan itu dia sering menggaruk berlebihan di tempat yang aneh aneh tadi", "anjing saya terus-terusan menggaruk hingga bulunya rontok. telinganya juga lecet. Banyak bintik botak dan bulu ekornya rontok.", "anjing saya sering garuk ujung telinganya sampe lecet, ada bintik botak dan keraknya juga, trus bulunya pada rontok terutama bulu ekor berminyak juga itu kenapa ya?"],
        "responses": ["Definisi:\nPemfigus merupakan penyakit kulit langka dan serius yang disebabkan karena adanya masalah pada sistem kekebalan tubuh. Penyakit ini ditandai dengan munculnya bula yang menyerupai bisul pada kulit atau membran mukosa (misalnya di dalam mulut atau alat kelamin). Bula ini mudah sekali pecah dan akan meninggalkan bekas seperti luka lepuh yang rentan menjadi sarang infeksi.\n\nPenyebab:\npenyebab pasti timbulnya pemfigus masih belum diketahui. Namun, faktor yang diduga menjadi penyebabnya adalah faktor genetik. Pemfigus lebih sering menyerang orang yang sudah mengidap penyakit autoimun lainnya (terutama miastenia gravis dan timoma).\n\nPenanganan:\n-Pengobatan membutuhkan penekanan kekebalan dan imunomodulator. Jangan mengobati daun pemphigus tanpa diagnosis dan penghapusan diferensial lainnya.\n1. Glukokortikoid adalah pengobatan awal yang paling umum, karena mereka adalah agen anti-inflamasi dan  imunomodulator yang kuat. Ada banyak mekanisme tindakan yang berguna dalam pengobatan penyakit kulit autoimun, tetapi yang paling menonjol adalah efek pada kekebalan humoral dan dimediasi sel, pertahanan fagosit, penghambatan mediator inflamasi, dan penekanan tingkat autoantibodi.\n2. Chlorambucil paling sering digunakan pada kucing ketika monoterapi glukokortikoid tidak cukup. Seseorang harus memantau myelosuppression selain muntah, diare, dan anoreksia. CBC dengan jumlah trombosit direkomendasikan sebelum pengobatan dan seperti yang ditunjukkan selama pengobatan.\n3. Chyrsotherapy adalah penggunaan garam emas. Penggunaan chrysotherapy dan glukokortikoid telah terbukti efektif dalam pengobatan feline PF. Garam emas memiliki efek imunomodulator dan anti-inflamasi.\n4. Siklosporin adalah obat imunosupresif nonsteroid yang kadang-kadang diresepkan. Respon klinis bervariasi dalam penyakit autoimun dan paling sering dilembagakan dalam upaya untuk mengurangi jumlah glukokortikoid yang digunakan. Efek samping termasuk muntah, diare, anoreksia, penurunan berat badan, hiperplasia gingiva, hirsutisme, dan papillomatosis. "],
        "context_set": [""]
    },
    {
        "tag": "Salmonella",
        "patterns": ["anjing saya kayaknya depresi sampai kena demam. Dehidrasi juga jadi Lelah gitu. Sama diarean sampai berdarah itu bahaya kan", "anjing saya kuping dan hidungnya panas, sepertinya dia demam. Ia juga diare berlebih disertai darah. terlihat sangat lemah.", "badan anjing saya panas tinggi seperti demam dan diare terus ada darahnya kaya depresi dan dehidrasi"],
        "responses": ["Definisi:\nSalmonellosis pada anjing merupakan suatu penyakit yang disebabkan oleh bakteri gram negatif Salmonella sp. dengan ditandai oleh adanya penyakit keradangan pada lambung dan usus (gastroenteritis), keguguran pada anjing yang sedang bunting (abortions), dan adanya multipikasi bakteri di dalam darah (septicemia).\n\nPenyebab:\nBakteri gram negatif  Salmonella sp. yang bersifat enterobakteria (beracun) berjumlah lebih dari 2000 tipe.\n\nPenanganan:\n- Hindarkan kontak dan akukan isolasi/karantina terhadap anjing penderita sampai benar-benar sembuh.\n- Memberikan antibiotik yang tepat untuk membunuh bakteri salmonella, obat anti radang dan anti muntah, fluid therapy (infus) untuk  mengatasi dehidrasi, dan vitamin untuk meningkatkan nafsu makannya. "],
        "context_set": [""]
    },
    {
        "tag": "Gastroenteritis",
        "patterns": ["anjing saya itu kayaknya kelelahan sampai sakit kepala sama nyeri otot. Mana sering muntah sampai diarean. Kena demam panas juga", "anjing saya diare dan muntah. ia juga terlihat kelelahan, lemah, dan tidak nafsu makan.", "anjing saya badannya lemes serta panas tinggi seperti demam, diare, dan muntah"],
        "responses": ["Definisi:\nLa gastroenteritis pada anjing itu adalah penyakit yang mirip dengan yang kita derita. Secara umum ini bukan penyakit yang serius, Anda tidak selalu harus pergi ke dokter hewan dan dalam sebagian besar kasus tidak berakibat fatal, tetapi hanya membutuhkan beberapa hari penyembuhan untuk anjing dan perawatan dasar di pihak kami sehingga itu pulih.\n\nPenyebab:\nRadang selaput lendir dapat terjadi karena berbagai faktor, dari virus hingga bakteri atau parasit. Ini bisa disebabkan oleh infeksi virus, jamur atau bakteri, tetapi juga karena makan makanan basi, makan tanaman beracun atau makan makanan yang tidak enak. Dalam situasi stres yang berkepanjangan, mukosa usus juga dapat diubah dan menyebar ketika terjadi kontak dengan anjing yang mengidap penyakit tersebut. Bergantung pada kesehatan anjing, ini bisa lebih atau kurang kuat.\n\nPenanganan:\nAerosol, Bubuk, Shampoo, Semprotan, Dips, Bilasan, Busa, Spot-ons. Disuntikkan, Tablet oral, Cairan oral, Berbagai jenis kerah yang diresapi "],
        "context_set": [""]
    },
    {
        "tag": "gastritis radang perut",
        "patterns": ["anjing saya sering bersendawa, nafsu makannya hilang tapi kalau mau makan malah kenyang dini. Perutnya juga malah kembung anehnya. Suka mual sama muntah habis makan. Pas dicek dia kena nyeri perut tengah atas, berat badannya juga turun ngga jelas gitu", "anjing saya muntah-muntah lebih dari 14 hari. Di muntahannya ada makanan dan cairan empedu. nafsu makannya juga menurun dan terlihat sakit perut.", "anjing saya muntah dan tidak nafsu makan sehingga beratnya turun drastis"],
        "responses": ["Definisi:\nGastritis merupakan peradangan, pengikisan, atau iritasi pada lapisan sistem pencernaan anjing. Apabila mukosa lambung terus-menerus meradang, maka dapat terjadi luka pada lambung yang menyebabkan infeksi atau bahkan sumbatan pada saluran cerna.\n\nPenyebab:\n>Gastritis dapat disebabkan oleh zat atau bahan makanan yang telah terkontaminasi, beracun, atau tidak dapat dicerna oleh anjing, seperti :\n-Makanan mentah\n-Makanan busuk\n-Kotoran kucing\n-Tanaman tertentu yang beracun bagi anjing\n-Makanan manusia yang beracun bagi anjing\n-Jamur atau kapang\n-Benda asing atau benda bukan makanan\n-Zat beracun seperti bahan kimia atau cairan pembersih\n-Obat-obatan.\n\n>Gastritis juga dapat disebabkan oleh :\n-Infeksi virus, bakteri, atau parasit\n-Paparan zat alergen dalam jangka waktu yang lama\n-Penyakit autoimun\n-Kanker perut\n-Gagal ginjal\n-Penyakit radang usus\n-Ulkus\n-Penyakit neurologis.\n\nPenanganan:\nAntasida adalah pengobatan umum untuk gastritis ringan hingga sedang. Ketika antasida tidak memberikan bantuan yang cukup, obat-obatan seperti H2 blocker dan inhibitor pompa proton yang membantu mengurangi jumlah asam sering diresepkan. Agen sitoprotektif dirancang untuk membantu melindungi jaringan yang melapisi perut dan usus kecil. Mereka termasuk obat sukralfat dan misoprostol. Jika NSAID diambil secara teratur, salah satu obat ini untuk melindungi perut juga dapat diambil. Agen sitoprotektif lainnya adalah bismut subsalicylate. Beberapa rejimen digunakan untuk mengobati infeksi H. pylori. Sebagian besar menggunakan kombinasi dua antibiotik dan inhibitor pompa proton. Terkadang bismut ditambahkan ke rejimen. "],
        "responses": ["Definisi:\nPerubahan warna atau sifat berminyak di sekitar pangkal ekor kucing Anda.\n\nPenyebab:\nKondisi ini disebabkan oleh kelenjar sebaceous yang terlalu aktif yang terletak di dekat pangkal ekor. Kelenjar sebaceous adalah kelenjar khusus yang menghasilkan sekresi lilin atau berminyak yang digunakan oleh folikel rambut. Dalam jumlah normal, minyak menjaga rambut tetap lembut dan fleksibel, tetapi sebum yang berlebihan dapat menyebabkan akumulasi lilin dan berminyak.\n\nPenanganan:\n1. Penting untuk menjaga area bersih dan bebas dari kotoran kulit\n2. Menggunakan sampo anti-seborrhea secara teratur untuk mencegah penumpukan akumulasi sebum yang berminyak serta untuk mencegah penumpukan rambut kusut.\n3. Dalam kasus di mana infeksi menjadi perhatian ketika terdapat bau dan cairan, antibiotik mungkin diperlukan.\n4. Seperti biasa, Anda disarankan untuk membawa kucing Anda ke dokter hewan untuk evaluasi menyeluruh. "],
        "context_set": [""]
    },
    {
        "tag": "Sporotrichosis",
        "patterns": ["kucing saya lemes ga mau makan dan ada benjol di kakinya", "kucing saya ada luka besar sekali di mukanya dan ada juga luka benjolan. ia tidak nafsu makan. saya lihat di kakinya juga ada infeksi.", "Kucing saya itu ada luka luka benjolan, lukanya berair sama berkerak. Dikakinya ada infeksi, mulutnya luka juga. Dihidungnya ada lesi sama luka lagi, di wajahnya ada lesi juga. Gara gara semua luka itu, dia nafsu makannya berkurang sampai hilang tidak mau makan lagi"],
        "responses": ["Definisi:\nInfeksi yang disebabkan oleh jamur yang disebut Sporothrix.\n\nPenyebab:\nLesi ini berkembang dari luka yang terjadi selama perkelahian dengan kucing yang terinfeksi. Kucing yang menjilati luka yang terinfeksi di bagian lain dari tubuhnya juga dapat memindahkan jamur ke wajah dan mulutnya.\n\nPenanganan:\n1. Itrakonazol adalah obat pilihan untuk sporotrikosis kucing.\n2. Untuk penyakit berat atau refrakter, kapsul kalium iodida adalah biasanya digunakan dalam kombinasi dengan itrakonazol.\n3. Durasi pengobatan biasanya pada setidaknya 1 bulan setelah klinis temuan menyelesaikan. "],
        "context_set": [""]
    },
    {
        "tag": "Kutu Lice kucing",
        "patterns": ["bulu kucing saya menipis dan warnanya pucet, dia sering garuk karena ada jerawat sama komedo", "kucing saya garuk-garuk terus, bulunya juga terlihat kusam dan menipis. ada jerawat dan komedo juga.", "Kucing saya itu komedoan, jerawatan, bulunya juga pucat sama kayak menipis gitu. Dia suka garukgarukin itu yg jerawatan ngga bahaya kah"],
        "responses": ["Definisi:\nKucing yang terserang kutu.\n\nPenyebab:\nTertular oleh kucing lain.\n\nPenanganan:\n1. Isolasi Kucing Anda: Ini hanya langkah yang diperlukan jika Anda memiliki lebih dari satu kucing di rumah Anda dan diperlukan untuk mencegah mentransfer kutu ke kucing lain.\n\n2. Perawatan Obat: Dokter hewan Anda akan merekomendasikan perawatan insektisida untuk kucing Anda, yang mungkin termasuk mencuci obat atau sampo. Yang terbaik adalah berbicara dengan dokter hewan Anda sehingga Anda dapat memastikan obat itu aman untuk kucing Anda.\n\n3. Perawatan Rumah: Anda juga dapat meminta dokter hewan Anda untuk merekomendasikan produk untuk menyingkirkan kutu di sekitar rumah. Ada berbagai semprotan dan bubuk yang dirancang untuk menghilangkan nits dan kutu dari rumah Anda. Ini adalah langkah penting.\n\n4. Mencukur Bulu: Dokter hewan Anda hanya akan merekomendasikan mencukur bulu jika kusut parah. Seharusnya tidak diperlukan untuk mengobati sebagian besar infeksi. "],
        "context_set": [""]
    },
    {
        "tag": "Ringworm kucing",
        "patterns": ["kucing saya bulunya rontok dan patah, sering garuk kulitnya yg kering merah ada bintik botaknya, dagunya bengkak, ada luka basah di belakang leher dan luka bulet di kaki bagian depan", "kucing saya garuk-garuk terus dan saya lihat ada kerak melingkar di badannya. kulitnya juga memerah dan ada luka basah di belakang leher. ada bintik botak dan bulunya rontok.", "Kucing saya ada kulit yg memerah gitu, ada keraknya, bintik botak, bulunya rontok, patah patah, ada ketombenya. Terus kulitnya kayak kering gitu, dagunya bengkak, ada luka aneh juga di kaki depan, sama basah dibelakan leher. Parahnya dia suka garuk itu yg berdarah sama berkerak itu"],
        "responses": ["Definisi:\nRingworm adalah infeksi kulit umum yang disebabkan oleh jamur. Disebut \"Ringworm\" karena dapat menyebabkan ruam melingkar (berbentuk seperti cincin) yang biasanya berwarna merah dan gatal.\n\nPenyebab: Jamur.\n\nPenanganan:\n1. Perawatan antijamur termasuk agen topikal seperti miconazole, terbinafine, clotrimazole, ketoconazole, atau tolnaftate diterapkan dua kali sehari sampai gejala sembuh. Biasanya dalam satu atau dua minggu.\n\n2. Perawatan topikal kemudian harus dilanjutkan selama 7 hari lebih lanjut setelah resolusi gejala yang terlihat untuk mencegah kekambuhan.\n\n3. Oleh karena itu, durasi total pengobatan umumnya dua minggu, tetapi mungkin selama tiga minggu.\n\n4. Dalam kasus yang lebih parah atau ruam kulit kepala, pengobatan sistemik dengan obat oral dapat diberikan.\n\n5. Untuk mencegah penyebaran infeksi, lesi tidak boleh disentuh, dan kebersihan yang baik dijaga dengan mencuci tangan dan tubuh. "],
        "context_set": [""]
    },
    {
        "tag": "Allergic Dermatitis kucing",
        "patterns": ["kucing saya bulunya rontok karena sering di garuk sampe merah kulitnya juga ada kerak", "kucing saya menggaruk berlebihan dan kulitnya memerah. beberapa hari yang lalu saya baru mengganti makanannya dengan merk yang lain", "kucing saya tu kulitnya memerah gitu, ada keraknya juga. Mana suka dia garuk lagi takut jadinya. Bulunya ada rontok juga, terus dia kena radang gitu"],
        "responses": ["Definisi:\nAlergi yang dialami oleh kucing dan mempengaruhi kondisi kulit kucing.\n\nPenyebab:\n1. Gigitan kutu\n2. Alergi makanan\n3. Alergi karena kondisi lingkungan.\n\nPenanganan:\n1. Dermatitis alergi pada kucing dapat diobati dengan beberapa cara, termasuk penghindaran alergen, terapi simtomatik, imunoterapi atau terapi penekan kekebalan tubuh.\n2. Menjauhkan kucing Anda dari sumber alergen.\n3. Terapi Simtomatik: Antimikroba, sampo obat, salep, suplemen dan obat-obatan lain dapat digunakan untuk mengobati gejala yang terkait dengan dermatitis alergi.\n4. Imunoterapi: Proses desensitisasi kucing terhadap alergen melalui penggunaan protein alergen.\n5. Terapi Imunosupresif: Mengobati kondisi kucing dengan steroid dan obat siklosporin untuk mengurangi respons imun. "],
        "context_set": [""]
    },
    {
        "tag": "Pemphigus kucing",
        "patterns": ["kucing saya panas tinggi hingga bulunya rontok dia sering garuk sampe kulitnya merah, badannya ada bopeng dan bengkak", "kucing saya garuk-garuk terus dan ada bopeng di sekitar mata. bagian pada tubuhnya juga ada yang bengkak.", "Kucing saya itu ada bengkak sama rontok bulunya. Kulitnya memerah, terus suka dia garuk ga jelas gitu. Dia juga kena demam kayaknya"],
        "responses": ["Definisi:\nPemphigus adalah sekelompok lima penyakit kulit autoimun yang ditandai dengan vesikel dan bula (\"lepuh\") besar dan kecil di mulut dan pada sambungan mukokutan (persimpangan antara kulit dan jaringan mukosa). Daerah yang sering terkena termasuk kelopak mata, bibir, lubang hidung, dan anus.\n\nPenyebab: Autoimun.\n\nPenanganan:\nPengobatan membutuhkan penekanan kekebalan dan imunomodulator. Jangan mengobati daun pemphigus tanpa diagnosis dan penghapusan diferensial lainnya.\n1. Glukokortikoid adalah pengobatan awal yang paling umum, karena mereka adalah agen anti-inflamasi dan  imunomodulator yang kuat. Ada banyak mekanisme tindakan yang berguna dalam pengobatan penyakit kulit autoimun, tetapi yang paling menonjol adalah efek pada kekebalan humoral dan dimediasi sel, pertahanan fagosit, penghambatan mediator inflamasi, dan penekanan tingkat autoantibodi.\n\n2. Chlorambucil paling sering digunakan pada kucing ketika monoterapi glukokortikoid tidak cukup. Seseorang harus memantau myelosuppression selain muntah, diare, dan anoreksia. CBC dengan jumlah trombosit direkomendasikan sebelum pengobatan dan seperti yang ditunjukkan selama pengobatan.\n\n3. Chyrsotherapy adalah penggunaan garam emas. Penggunaan chrysotherapy dan glukokortikoid telah terbukti efektif dalam pengobatan feline PF. Garam emas memiliki efek imunomodulator dan anti-inflamasi.\n\n4. Siklosporin adalah obat imunosupresif nonsteroid yang kadang-kadang diresepkan. Respon klinis bervariasi dalam penyakit autoimun dan paling sering dilembagakan dalam upaya untuk mengurangi jumlah glukokortikoid yang digunakan. Efek samping termasuk muntah, diare, anoreksia, penurunan berat badan, hiperplasia gingiva, hirsutisme, dan papillomatosis. "],
        "context_set": [""]
    },
    {
        "tag": "Feline Acne",
        "patterns": ["kucing saya bulunya jadi pucet dan tipis, ada luka benjol bernanah, dan jerawat juga komedo di dagu", "kucing saya ada luka berbentuk benjolan dan bernanah. warna bulunya pucat dan di sekitar dagunya ada jerawat", "Kucing saya ada luka benjolan bernanah ih. Bulunya juga menipis warnanya memucat. juga Komedoan sama jewaratan disekitar dagu "],
        "responses": ["Definisi:\nKucing yang berjerawat memiliki banyak komedo di dagu dan bibirnya, dan dagunya mungkin tampak \"kotor\". Komedo dapat berkembang menjadi abses kecil yang pecah dan membentuk krusta. Dalam kasus yang parah, saluran pengeringan, rambut rontok, dan pembengkakan dapat terjadi di dagu. Ini mungkin gatal dan menyebabkan kucing Anda menggaruk, yang dapat menyebabkan lebih banyak trauma pada area tersebut. Infeksi bakteri sekunder sering berkembang.\n\nPenyebab:\nBeberapa faktor tampaknya terkait dengan perkembangannya termasuk stres, sistem kekebalan yang menurun, kebiasaan perawatan yang buruk, adanya penyakit lain, kontak atau dermatitis atopik, dan kondisi kulit di mana jumlah yang tidak normal. minyak diproduksi dan folikel rambut tidak berfungsi dengan baik.\n\nPenanganan:\n1. Karena beberapa kucing alergi terhadap plastik, Anda harus beralih ke mangkuk makanan dan air dari baja tahan karat. Cuci mangkuk setiap hari dengan sabun dan air panas. Piring yang dangkal dapat mencegah kontak dengan dagu.\n\n2. Tisu obat dapat digunakan untuk kucing yang rentan mengalami jerawat di dagu atau untuk kucing yang memiliki kebiasaan perawatan yang buruk.\n\n3. Sampo antiseboroik, seperti yang mengandung benzoil peroksida (pada konsentrasi 3% atau kurang) atau gel benzoil peroksida dapat digunakan untuk memecah minyak berlebih dan membersihkan pori-pori.\n\n4. Suplementasi dengan asam lemak mungkin bermanfaat.\n\n5. Antibiotik oral atau topikal, seperti mupirocin, dapat digunakan jika ada infeksi bakteri sekunder.\n\n6. Jika ada peradangan dalam jumlah besar, kortikosteroid jangka pendek, seperti prednisolon, dapat diresepkan. "],
        "context_set": [""]
    },
    {
        "tag": "Cat Scratch Disease",
        "patterns": ["kucing saya demam udah berhari-hari, ada cacing dimuntahannya, matanya merah, dan lemes karena ga mau makan", "kucing saya muntah-muntah dan saya lihat di dekat lehernya ada benjolan. apa kelenjar getah beningnya bengkak? matanya memerah dan ia terlihat kelelahan. ", "Kucing saya udah demam 3 hari, dia kelelahan sama muntah muntah gitu. Mana ada cacing di muntahnya. Matanya memerah, sama pas dicek kelenjar getah beningnya membengkak. Itu semua membuat dia tidak nafsu makan lagi "],
        "responses": ["Definisi:\nCat scratch disease (CSD) adalah infeksi yang disebabkan oleh bakteri Bartonella henselae, dan spesies Bartonella lainnya yang lebih jarang.\n\nPenyebab:\nKucing dapat terinfeksi B. henselae dari gigitan kutu dan kotoran kutu (kotoran) yang masuk ke dalam lukanya. Dengan menggaruk dan menggigit kutu, kucing mengambil kotoran kutu yang terinfeksi di bawah kuku dan sela-sela giginya.\n\nPenanganan:\n1. Gunakan produk perawatan dan pencegahan kutu yang efektif direkomendasikan dan tersedia dari dokter hewan Anda.\n\n2. Bicaralah dengan dokter hewan Anda tentang pengujian dan perawatan untuk kucing Anda. Dokter hewan Anda dapat memberi tahu Anda apakah kucing Anda memerlukan pengujian atau perawatan. "],
        "context_set": [""]
    },
    {
        "tag": "Giardia",
        "patterns": ["kucing saya pup terus dan fesesya berminyak", "kucing saya diare dan terlihat pupnya berminyak", "Kucing saya diarean sampai BABnya berminyak. Dia juga dehidrasi gitu"],
        "responses": ["Definisi:\nGiardia adalah parasit kecil (kuman) yang menyebabkan penyakit diare giardiasis. Giardia ditemukan di permukaan atau di tanah, makanan, atau air yang telah terkontaminasi dengan kotoran (kotoran) dari orang atau hewan yang terinfeksi.\n\nPenyebab:\n1. Berada dalam kontak dengan kotoran yang terinfeksi dari anjing atau kucing lain\n\n2. Berguling dan bermain di tanah yang terkontaminasi\n\n3. Menjilat tubuhnya setelah kontak dengan permukaan yang terkontaminasi (misalnya, kotak kotoran atau kandang anjing atau peti yang kotor)\n\n4. Minum air dari sungai, kolam, atau badan air lain yang terkontaminasi.\n\nPenanganan:\n1. Jika hewan peliharaan Anda mengalami diare yang tidak kunjung sembuh, carilah perawatan dokter hewan. Diare memiliki penyebab yang berbeda dan dapat mengakibatkan dehidrasi atau masalah serius lainnya.\n\n2. Diagnosis dan pengobatan infeksi Giardia harus dilakukan oleh dokter hewan berlisensi.\n\n3. Tidak ada pengobatan bebas yang disetujui yang tersedia untuk infeksi Giardia.\n\n4. Giardia dapat ditularkan melalui kotoran secara singkat, dan seekor hewan mungkin tampak sehat atau tanpa tanda-tanda penyakit sebelum ia berhenti mengeluarkan Giardia. Tes kotoran berulang mungkin diperlukan.\n\n5. Ikuti rekomendasi dokter hewan Anda dan bawa hewan peliharaan Anda ke semua janji tindak lanjut."],
        "context_set": [""]
    },
    {
        "tag": "Leptospirosis",
        "patterns": ["mata dan mulut kucing saya berwarna kuning, berat badannya turun ga nafsu makan lemes banget, badannya panas banget, pipisnya berdarah", "kucing saya pipisnya berdarah dan muntah-muntah. ia tidak mau makan hingga berat badannya juga berkurang. saya perhatikan mulut dan mata kuning", "Kucing saya itu lemah lesu sampai demam pucat sama diarean muntah gitu. Berat badannya berkurang kurus, dehidrasi, nafsu makannya juga berkurang sampai hilang tidak mau makan. Mata sama mulutnya kekuningan ada salah makan kah? Kencingnya berdarah lagi"],
        "responses": ["Definisi:\nLeptospirosis adalah infeksi darah yang disebabkan oleh bakteri Leptospira.\n\nPenyebab:\nTerpapar urin atau liur dari hewan terinfeksi lainnya.\n\nPenanganan:\n1. Diet khusus melalui infus\n2. Diberi antibiotik secepatnya karena bila melewati 7 hari sejak mulai timbul gejala kurang bermanfaat. "],
        "context_set": [""]
    },
    {
        "tag": "Cacing Pita Kucing",
        "patterns": ["ada sesuatu warnanya putih kecil bergerak di pup kucing saya", "kucing saya di pantatnya ada putih-putih kecil bergerak", "Kucing saya ada putih putih kecil bergerak di kotorannya"],
        "responses": ["Definisi:\nCacing pita kucing adalah parasit yang menyebar ke anjing, kucing, dan manusia melalui konsumsi kutu yang terinfeksi. Parasit ini umum pada kucing tetapi jarang menyebabkan penyakit pada hewan peliharaan atau manusia.\n\nPenyebab:\nCacing pita menyebar ketika kucing atau orang menelan kutu yang terinfeksi.\n\nPenanganan:\n1. Obat resep yang disebut praziquantel diberikan, baik secara oral atau injeksi (khusus hewan peliharaan). Obat tersebut menyebabkan cacing pita larut di dalam usus. Karena cacing biasanya dicerna sebelum lewat, cacing itu mungkin tidak terlihat di kotoran kucing Anda. Obat-obatan umumnya ditoleransi dengan baik.\n2. Bicaralah dengan dokter hewan Anda tentang pengujian dan perawatan untuk kucing Anda. Dokter hewan Anda dapat memberi tahu Anda apakah kucing Anda memerlukan pengujian atau perawatan. "],
        "context_set": [""]
    },
    {
        "tag": "Cacing Tambang Kucing",
        "patterns": ["perut kucing saya buncit tapi berat badannya turun dan kurusan", "kucing saya badannya mengurus tetapi perutnya membuncit. dan dia seperti kurang darah.", "Kucing saya kena anemia sampai berat badannya berkurang kurus, tapi anehnya perutnya malah membucit. Ada infeksi juga kayaknya"],
        "responses": ["Definisi:\nCacing tambang adalah cacing kecil yang dapat menyebar melalui kontak dengan tanah atau pasir yang terkontaminasi.\n\nPenyebab:\nKucing menelan tanah atau air yang mengandung larva.\n\nPenanganan:\n1. Berikan pirantel palmoat dan milbemycin oxime secara oral\n2. Berikan selamectin secara topikal (dioleskan). Tidak cocok untuk kucing < 8 minggu "],
        "context_set": [""]
    },
    {
        "tag": "Feline Chlamydia",
        "patterns": ["mata kucing saya bengkak berair, dia juga lemes batuk pilek terus", "kucing saya batuk-batuk dan bersin. pernapasannya terganggu. hidungnya berair dan ada cairan putih pada mata", "Kucing saya sering batuk sama bersin sampai kena gangguan pernafasan kayaknya, hidungnya juga meler ingusan berair gitu. Matanya bengkak merah berair, sering nyipitkan mata atau nutup sebelah mata, ada cairannya juga kadang kuning kadang putih. Semua itu membuat dia lemah lesu gimana ya"],
        "responses": ["Definisi:\nChlamydia kucing adalah penyakit yang disebabkan oleh infeksi bakteri Chlamydia felis (C. felis).\n\nPenyebab:\nTerpapar tetesan cairan yang keluar dari mata atau hidung kucing yang terinfeksi penyakit ini.\n\nPenanganan:\n1. Dibutuhkan pemeriksaan fisik menyeluruh oleh Dokter Hewan untuk menentukan apakah kucing Anda terkena chlamydia\n\n2. Antibiotik biasanya diberikan untuk mengobati klamidia pada kucing. Biasanya diberikan Tetrasiklin.\n\n3. Jika klamidia hanya mempengaruhi mata kucing Anda, maka antibiotik topikal, yang dioleskan langsung ke mata itu sendiri, mungkin berhasil mengobati infeksi.\n\n4. Jika infeksinya parah atau telah menyebar ke saluran pernapasan atas atau bawah, kucing Anda mungkin memerlukan terapi antibiotik oral atau suntik.\n\n5. Antibiotik biasanya membawa kesembuhan yang cepat pada infeksi klamidia, meskipun begitu kucing Anda perlu terus menggunakannya hingga tiga minggu, bahkan setelah gejalanya hilang.\n\n6. Jika kucing Anda tidak mulai membaik dengan cepat dengan pengobatan, atau jika kondisinya tampak memburuk meskipun telah diobati, hubungi dokter hewan Anda. Kucing Anda mungkin menderita infeksi virus yang menghambat pemulihannya."],
        "context_set": [""]
    },
    {
        "tag": "Distemper kucing",
        "patterns": ["mata kucing saya merah dan berair, kulitnya kering, pupnya berdarah, badannya panas banget", "kucing saya sangat kurus. beberapa hari ini diare berdarah dan muntah-muntah hingga dehidrasi. ia tidak aktif seperti biasanya dan hanya telentang dengan kaki ke atas dan kepala terkulai. hidungnya berair dan matanya merah.", "Kucing saya demam, panas dia. Kena diare juga, mana bau lagi. Kayaknya kena dehidrasi juga dia"],
        "responses": ["Definisi:\nDistemper kucing, disebut juga feline panleukopenia (FPV) adalah penyakit virus yang bisa menjangkiti kucing dan bersifat sangat menular dan sangat mematikan sehingga berpotensi mengancam nyawa. Penyakit ini menyerang sel darah merah di saluran usus, sumsum tulang, kulit, dan sel induk. Penyakit ini juga bisa memicu anemia serta penyakit virus dan bakteri lainnya. Setelah menghancurkan sel darah merah, infeksi akan mudah menyerang kucing karena tidak ada sistem pertahanan tubuh yang melindungi kucing.\n\nPenyebab:\nDistemper disebabkan adanya kontak yang dilakukan kucing terhadap saliva, kotoran hidung, darah, air seni, hingga feses dari kucing yang telah terinfeksi. Bahkan, kutu juga bisa menjadi perantara penularan penyakit ini.\n\nPenanganan:\n1. Begitu kamu menemukan gejala-gejala penyakit distemper pada kucingmu, segera konsultasikan dengan dokter hewan langgananmu.\n\n2. Kucing yang menderita distemper harus dikarantina untuk menghindari penyebaran virus ke kucing lain.\n\n3. Sebagai pemilik, kamu harus menyediakan berbagai kebutuhan nutrisinya agar kucing tidak mengalami dehidrasi maupun malnutrisi.\n\n4. Beberapa tes yang akan dilakukan antara lain:\n- Tes virus leukemia kucing (FeLV)\n- Tes virus imunodefisiensi kucing (FIV)\n- Perhitungan darah lengkap (Complete Blood Count/CBC)\n- Tes elektrolit\n- Tes urin dan feses\n- Foto rontgen dada dan perut"],
        "context_set": [""]
    }
  ]
}
# Out:
# {'intents': [{'patterns': ['hi',
#     'hai',
#     'hey',
#     'hei',
#     'apakah ada orang disana?',
#     'hello',
#     'halo',
#     'hay',
#     'ini itu apa ya?'],
#    'responses': ['Hallo saya Kuji! Saya disini siap membantu kamu',
#     'Hallo saya Kuji! Ada yang bisa saya bantu?',
#     'Hallo saya Kuji!, asisten bot yang siap membantu kamu'],
#    'tag': 'pembuka'},
#   {'patterns': ['terima Kasih',
#     'bye',
#     'thanks',
#     'thank you',
#     'ini sangat membantu',
#     'terima Kasih untuk bantuannya',
#     'oke mks'],
#    'responses': ['Terima Kasih sudah menggunakan TemanHewan',
#     'Semoga lekas sembuh',
#     'Senang bisa membantu kamu',
#     'Sama-sama!',
#     'Semoga semuanya segera membaik, Kuji selalu siap membantu kamu disini 24/7'],
#    'tag': 'penutup'},
#   {'patterns': ['tolong bantu saya',
#     'apa yang dapat anda lakukan untuk saya?',
#     'tolong hewan saya',
#     'saya butuh bantuan'],
# ...

# %% [markdown]
# ## **Model**

# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b673355-f32a-4ed8-8920-138a753de7ba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b673355-f32a-4ed8-8920-138a753de7ba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving intent.json to intent.json

# %%
# Separating labels and responses
with open('intent.json') as file:
    data = json.load(file)
    
training_sentences = []
training_labels = []
labels = []
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        training_sentences.append(pattern)
        training_labels.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
num_classes
# Out:
# 35

# %%
lbl_encoder = LabelEncoder()
lbl_encoder.fit(training_labels)
training_labels = lbl_encoder.transform(training_labels)

# %%
vocab_size = 1000
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_token)
tokenizer.fit_on_texts(training_sentences)
word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(training_sentences)
padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding (Embedding)       (None, 20, 16)            16000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 35)                595
#
# ...
# Total params: 17,139
# Trainable params: 17,139
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(training_labels), epochs=epochs)
# Out:
# Epoch 1/500
# 4/4 [==============================] - 1s 4ms/step - loss: 3.5548 - accuracy: 0.0508
# Epoch 2/500
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5520 - accuracy: 0.0593
# Epoch 3/500
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5496 - accuracy: 0.0593
# Epoch 4/500
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5465 - accuracy: 0.0593
# Epoch 5/500
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5436 - accuracy: 0.0593
# Epoch 6/500
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5403 - accuracy: 0.0593
# Epoch 7/500
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5368 - accuracy: 0.0678
# Epoch 8/500
# 4/4 [==============================] - 0s 5ms/step - loss: 3.5326 - accuracy: 0.0678
# Epoch 9/500
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5275 - accuracy: 0.0678
# Epoch 10/500
# ...

# %%
# to save the trained model
model.save("chat_model")

import pickle

# to save the fitted tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
# to save the fitted label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(lbl_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model/assets

# %%
pip install colorama
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

with open("intent.json") as file:
    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),
                                             truncating='post', maxlen=max_len))
        tag = lbl_encoder.inverse_transform([np.argmax(result)])

        for i in data['intents']:
            if i['tag'] == tag:
                print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))

        # print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL,random.choice(responses))

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()
# Out:
# Start messaging with the bot (type quit to stop)!
# User: hai
# ChatBot: Hallo saya Kuji!, asisten bot yang siap membantu kamu
# User: tolong bantu saya
# ChatBot: Jelaskan pada saya bagaimana keadaan hewan peliharaan mu?
# User: anjing saya sering garuk ujung telinganya sampe lecet, ada bintik botak dan keraknya juga, trus bulunya pada rontok terutama bulu ekor berminyak juga itu kenapa ya?
# ChatBot: Definisi:
# ...
